# %% [markdown]
# ### Notebook Imports

# %%
import requests
import time

from bs4 import BeautifulSoup
import pandas as pd
import concurrent.futures
import datetime

from transformers import pipeline

import gc
import torch
gc.collect()
torch.cuda.empty_cache()

month_dict = {
    'January': '01', 'February': '02', 'March': '03', 'April': '04', 'May': '05', 
    'June': '06', 'July': '07', 'August': '08', 'September': '09', 'October': '10', 
    'November': '11', 'December': '12' 
}

short_month_dict = {
    'Jan': '01', 'Feb': '02', 'Mar': '03', 'Apr': '04', 'May': '05', 'Jun': '06', 'Jul': '07', 
    'Aug': '08', 'Sep': '09', 'Oct': '10', 'Nov': '11', 'Dec': '12' 
}

# %% [markdown]
# ### https://climate.mit.edu/news Rate(0.2 sec/article)

# %%
def scrape_mit(n_articles = 10):
    links_mit = []

    n_actual = 0
    k = 0
    while n_actual <= n_articles:
        URL_mit = "https://climate.mit.edu/news?sort_bef_combine=created_DESC&sort_by=created&sort_order=DESC&page=" + str(k)
        page_mit = requests.get(URL_mit)
        soup_mit = BeautifulSoup(page_mit.content, "html.parser")
        results_mit = soup_mit.find_all(class_="field-group-link card-link")
        k += 1


        for i in results_mit:
            try: 
                if ( i.find(class_="pseudo-author").get_text() == "MIT News"):
                    link = i['href']
                    links_mit.append("https://climate.mit.edu" + link)
                    n_actual += 1
            except:
                continue
        
    data_mit = pd.DataFrame(columns=['title', 'content', 'date'])

    def fetch(url):
        response = requests.get(url)
        return response.content

    def convert_date(date):
        date = date.split(" ")
        day = date[1].replace(",", "")
        month = date[0]
        year = date[2]
        month = month_dict[month]
        return year + "-" + month + "-" + day

    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(fetch, links_mit[:n_articles]))

    for i in range(n_articles):
        article_soup = BeautifulSoup(results[i], "html.parser")
        title = article_soup.find(class_='faux-full-title').get_text()
        date = article_soup.find(class_='type-date').get_text().replace("\n", " ").replace("\xa0", "")
        date = convert_date(date)
        content = article_soup.find(class_='clearfix text-formatted field field--name-body field--type-text-with-summary field--label-hidden field__item').get_text().replace("\n", " ").replace("\xa0", "")
        #content = summarizer(content)[0]['summary_text']
        data_mit = pd.concat([data_mit, pd.DataFrame({'title': [title], 'content': [content], 'date': [date], 'source': ["MIT"], 'url': [links_mit[i]]})], ignore_index=True)

    return data_mit

# %% [markdown]
# ### https://www.iea.org/news (Rate: 0.2sec/article)

# %%
def scrape_iea(n_articles = 10):
    n_pages = n_articles // 24 + 1
    links_iea = []

    for i in range(1, n_pages+1):
        URL_iea = "https://www.iea.org/news?page=" + str(i)
        page_iea = requests.get(URL_iea)
        soup_iea = BeautifulSoup(page_iea.content, "html.parser")
        results_iea = soup_iea.find_all("article")

        for i in results_iea:
            link = i.find('a')['href']
            links_iea.append("https://www.iea.org/" + link)
        
    data_iea = pd.DataFrame(columns=['title', 'content', 'date'])

    def fetch(url):
        response = requests.get(url)
        return response.content

    def convert_date(date):
        date = date.split(" ")
        day = date[0]
        month = date[1]
        year = date[2]
        month = month_dict[month]
        return year + "-" + month + "-" + day

    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(fetch, links_iea[:n_articles]))

    for i in range(n_articles):
        article_soup = BeautifulSoup(results[i], "html.parser")
        title = article_soup.find(class_='o-hero-freepage__title f-title-3').get_text()
        date = article_soup.find(class_='o-hero-freepage__meta').get_text().replace("\n", " ").replace("\xa0", "")
        date = convert_date(date)
        content = article_soup.find(class_='m-block m-block--text').get_text().replace("\n", " ").replace("\xa0", "")
        #content = summarizer(content)[0]['summary_text']
        data_iea = pd.concat([data_iea, pd.DataFrame({'title': [title], 'content': [content], 'date': [date], 'source': ["IEA"], 'url': [links_iea[i]]})], ignore_index=True)

    return data_iea

# %% [markdown]
# ### https://www.rechargenews.com/latest (Rate: 0.2sec/article)

# %%
def scrape_rn(n_articles = 10):
    n_pages = n_articles // 20 + 1
    links_rn = []

    for i in range(1, n_pages+1):
        URL_rn = "https://www.rechargenews.com/latest?page=" + str(i)
        page_rn = requests.get(URL_rn)
        soup_rn = BeautifulSoup(page_rn.content, "html.parser")
        results_rn = soup_rn.find_all(class_="teaser-body-image")

        for i in results_rn:
            link = i.find('a')['href']
            links_rn.append("https://www.rechargenews.com" + link)
        
    data_rn = pd.DataFrame(columns=['title', 'content', 'date'])

    def fetch(url):
        response = requests.get(url)
        return response.content

    def convert_date(date):
        date = date.split(" ")
        day = date[3]
        month = date[4]
        year = date[5]
        month = month_dict[month]
        return year + "-" + month + "-" + day

    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(fetch, links_rn[:n_articles]))

    for i in range(n_articles):
        try:
            article_soup = BeautifulSoup(results[i], "html.parser")
            title = article_soup.find(class_='fs-xxl fw-bold mb-4 article-title ff-sueca-bold').get_text().replace("\n", " ").replace("\xa0", "")
            date = article_soup.find(class_='pr-3').get_text().replace("\n", " ").replace("\xa0", "")
            date = convert_date(date)
            content = article_soup.find(class_='article-body').get_text().replace("\n", " ").replace("\xa0", "")
        #content = summarizer(content)[0]['summary_text']
    
        except:
            continue
        data_rn = pd.concat([data_rn, pd.DataFrame({'title': [title], 'content': [content], 'date': [date], 'source': ["Recharge News"], 'url': [links_rn[i]]})], ignore_index=True)

    return data_rn

# %% [markdown]
# ### https://www.euronews.com/tag/energy (Rate: 0.2sec/article)

# %%
def scrape_en(n_articles = 10):
    n_pages = n_articles // 20 + 1
    links_en = []

    for i in range(1, n_pages+1):
        URL_en = "https://www.euronews.com/tag/energy?p=" + str(i)
        page_en = requests.get(URL_en)
        soup_en = BeautifulSoup(page_en.content, "html.parser")
        results_en = soup_en.find_all(class_="m-object__title qa-article-title")

        for i in results_en:
            link = i.find('a')['href']
            links_en.append("https://www.euronews.com" + link)
        
    data_en = pd.DataFrame(columns=['title', 'content', 'date'])

    def fetch(url):
        response = requests.get(url)
        return response.content

    def convert_date(date):
        date = date.split(":")
        date[1] = date[1].split(" ")
        date[1] = date[1][0]
        day = date[1].split("/")[0]
        month = date[1].split("/")[1]
        year = date[1].split("/")[2]
        return year + "-" + month + "-" + day

    results = []
    with concurrent.futures.ThreadPoolExecutor() as executor:
        for url in links_en[:n_articles]:
            future = executor.submit(fetch, url)
            results.append(future)
    results = [future.result() for future in results]

    for i in range(n_articles):
        try:
            article_soup = BeautifulSoup(results[i], "html.parser")
            for script in article_soup(["script", "style"]):
                script.decompose()
            title = article_soup.find(class_='c-article-title').get_text().replace("\n", " ").replace("\xa0", "")
            date = article_soup.find(class_='c-article-date').get_text().replace("\n", " ").replace("\xa0", "")
            date = convert_date(date)
            content = article_soup.find(class_='js-responsive-iframes-container').get_text().replace("\n", " ").replace("\xa0", "")
        except:
            continue
        # with torch.no_grad():
        #     content = summarizer(content)[0]['summary_text']
        data_en = pd.concat([data_en, pd.DataFrame({'title': [title], 'content': [content], 'date': [date], 'source': ["Euronews"], 'url': [links_en[i]]})], ignore_index=True)

    return data_en

# %% [markdown]
# ### https://mercomindia.com/archive/ (0.1 sec/article)

# %%
def scrape_mi(n_articles = 10):
    n_pages = n_articles // 5 + 1
    links_mi = []

    for i in range(1, n_pages+1):
        URL_mi = "https://mercomindia.com/archive/page-" + str(i)
        page_mi = requests.get(URL_mi)
        soup_mi = BeautifulSoup(page_mi.content, "html.parser")
        results_mi = soup_mi.find_all(class_="pt-cv-title")

        for i in results_mi:
            link = i.find('a')['href']
            links_mi.append(link)
        
    data_mi = pd.DataFrame(columns=['title', 'content', 'date'])

    def fetch(url):
        response = requests.get(url)
        return response.content

    def convert_date(date):
        date = date.split(" ")
        day = date[2].replace(",", "")
        month = date[1]
        year = date[3]
        month = short_month_dict[month]
        return year + "-" + month + "-" + day

    with concurrent.futures.ThreadPoolExecutor() as executor:
        results = list(executor.map(fetch, links_mi[:n_articles]))

    for i in range(n_articles):
        article_soup = BeautifulSoup(results[i], "html.parser")
        title = article_soup.find("div", {"id": "page-title-text"}).get_text().replace("\n", " ").replace("\xa0", "")
        date = article_soup.find(class_='entry-date').get_text().replace("\n", " ").replace("\xa0", "")
        date = convert_date(date)
        content = article_soup.find(class_='entry-content').get_text().replace("\n", " ").replace("\xa0", "").split("Listen to this article ")[1]
        #content = summarizer(content)[0]['summary_text']
        data_mi = pd.concat([data_mi, pd.DataFrame({'title': [title], 'content': [content], 'date': [date], 'source': ["Mercom India"], 'url': [links_mi[i]]})], ignore_index=True)

    return data_mi

# %%
def main(n_articles_per_source):
    with concurrent.futures.ThreadPoolExecutor(max_workers=5) as executor:
        
        data_mit = executor.submit(scrape_mit, n_articles_per_source)
        data_iea = executor.submit(scrape_iea, n_articles_per_source)
        data_rn = executor.submit(scrape_rn, n_articles_per_source)
        data_en = executor.submit(scrape_en, n_articles_per_source)
        data_mi = executor.submit(scrape_mi, n_articles_per_source)

        
        data_mit = data_mit.result()
        data_iea = data_iea.result()
        data_rn = data_rn.result()
        data_en = data_en.result()
        data_mi = data_mi.result()

    data = pd.concat([data_mit, data_iea, data_rn, data_en, data_mi], ignore_index=True)
    data['date'] = pd.to_datetime(data['date'])
    data = data.sort_values(by=['date'], ascending=False)
    return data

# %%
data = main(10)
data
# Out:
#                                                 title  \
# 20     Shell-EDF sign on for New Jersey Wind Port ...
# 30               Gas pipeline explosion in Lithuan...
# 0   Computers that power self-driving cars could b...
# 41  Daily News Wrap-Up: REC India Commits ₹10 Bill...
# 40  Kerala’s ANERT Invites Bids to Procure 1,000 S...
# 39  Solar PV Soiling Likely to Cut 4-5% of Energy ...
# 31               Gas pipeline explodes in Lithuani...
# 26     US offshore wind regulator sees new permitt...
# 25     China's Mingyang looks 'beyond 18MW' with 1...
# 23     UK needs 'onshore wind and solar revolution...
# 22     US offshore winds of change, revolutions in...
# 21     Green giant Orsted presses go on largest so...
# 24     'Red flag for green power' | South Korea sl...
# 42  Karnataka Regulator Cuts Permissible Deviation...
# 10  The world is entering a new age of clean techn...
# 29     Thor's hammer! Siemens Gamesa lands 1GW ord...
# 28     'Too much and too fast' | Whale beachings s...
# 27     Broadwind hails 'transformational' tower or...
# 43  Tech Firm Entuple E-Mobility Secures $3 Millio...
# 1   Study: Extreme heat is changing habits of dail...
# 2   Looking to the past to prepare for an uncertai...
# 32               German police start removing clim...
# 11  Hydrogen patents indicate shift towards clean ...
# 44  Renewable Energy Firm Silicon Ranch Raises $60...
# 3    A new way to assess radiation damage in reactors
# 45  Sunrun to Expand Assets Using Recently Secured...
# 46  Karnataka Invites Bids for Solarization of Agr...
# 47  Punjab Regulator Allows DISCOM to Carry Forwar...
# 48  Data-based Decision-making Vital for Africa’s ...
# 12  Executive Director meets with Prime Minister F...
# 33               Eurozone inflation drops for a se...
# 4   New MIT internships expand research opportunit...
# 34               Europe's gas prices reach pre-war...
# 5    Sustainable supply chains put the customer first
# 35               Finland opens floating liquified ...
# 36               Serbians are in a festive mood an...
# 6             MIT community in 2022: A year in review
# 37               The EU has approved a €28 billion...
# 7                      Manufacturing a cleaner future
# 8   New sensor uses MRI to detect light deep in th...
# 9   Evelyn Wang appointed as director of US Depart...
# 38               Hungary, Romania, Georgia, Azerba...
# 13  The world’s coal consumption is set to reach a...
# 14  How the European Union can avoid natural gas s...
# 15  IEA and Ukraine deepen bilateral cooperation w...
# 16  Global government spending on clean energy tra...
# 17  Renewable power’s growth is being turbocharged...
# 18  Global energy efficiency progress is accelerat...
# 19  The global energy crisis is driving a surge in...
#
#                                               content       date  \
# 20  The Shell-EDF joint venture (JV) behind the At... 2023-01-14
# 30  An explosion in a gas pipeline in central Lith... 2023-01-14
# 0   In the future, the energy needed to run the po... 2023-01-13
# 41                  Here are some noteworthy clean... 2023-01-13
# 40                  The Agency for New & Renewable... 2023-01-13
# 39                  The soiling of solar photovolt... 2023-01-13
# 31  A gas pipeline has exploded in Lithuania, acco... 2023-01-13
# 26  The federal energy regulator in US coastal wat... 2023-01-13
# 25  Mingyang Smart Energy set out its stall to tak... 2023-01-13
# 23  The UK should set clear roadmaps for an onshor... 2023-01-13
# 22  US offshore wind this week saw the departure o... 2023-01-13
# 21  Orsted confirmed a final investment decision (... 2023-01-13
# 24  South Korea was accused of snubbing the needs ... 2023-01-13
# 42                  The Karnataka Electricity Regu... 2023-01-12
# 10    The energy world is at the dawn of a new ind... 2023-01-12
# 29  German utility RWE has selected Siemens Gamesa... 2023-01-12
# 28  A consortium of environmental and fisheries ac... 2023-01-12
# 27  Independent tower manufacturer Broadwind annou... 2023-01-12
# 43                  Electric powertrains technolog... 2023-01-12
# 1   Extreme temperatures make people less likely t... 2023-01-12
# 2   Aviva Intveld, an MIT senior majoring in Earth... 2023-01-11
# 32  A police operation is underway to remove prote... 2023-01-11
# 11    Hydrogen technology development is shifting ... 2023-01-10
# 44                  Nashville-based Silicon Ranch,... 2023-01-10
# 3    A new method could greatly reduce the time an... 2023-01-10
# 45                  U.S.-based residential solar c... 2023-01-10
# 46                  Karnataka Renewable Energy Dev... 2023-01-10
# 47                  The Punjab State Electricity R... 2023-01-10
# 48                  The Renewable Energy Performan... 2023-01-10
# 12    IEA Executive Director Faith Birol had a bil... 2023-01-09
# 33             ByLuke Hurst               &Natalie... 2023-01-06
# 4   With new support from the Office of the Associ... 2023-01-05
# 34  Europe's gas prices have reached pre-war level... 2023-01-05
# 5   When we consider the supply chain, we typicall... 2023-01-04
# 35  Like many countries in Europe, Finland is look... 2022-12-28
# 36  There used to be lights from as early as Octob... 2022-12-26
# 6   In 2022, MIT returned to a bit of normalcy aft... 2022-12-23
# 37                 ByEuronews Green              w... 2022-12-22
# 7   Manufacturing had a big summer. The CHIPS and ... 2022-12-22
# 8   Using a specialized MRI sensor, MIT researcher... 2022-12-22
# 9   On Thursday, the United States Senate confirme... 2022-12-22
# 38  The leaders of Azerbaijan, Georgia, Hungary, a... 2022-12-17
# 13    Global coal demand is set to increase only m... 2022-12-16
# 14    The European Union faces a potential shortfa... 2022-12-12
# 15    The IEA and Ukraine today signed a two-year ... 2022-12-12
# 16    Global government spending to support clean ... 2022-12-09
# 17    The global energy crisis is driving a sharp ... 2022-12-06
# 18    Energy efficiency actions have accelerated g... 2022-12-02
# 19    Worldwide sales of heat pumps are set to soa... 2022-11-30
#
#            source                                                url
# 20  Recharge News  https://www.rechargenews.com/solar/shell-edf-s...
# 30       Euronews  https://www.euronews.com/2023/01/14/gas-pipeli...
# 0             MIT  https://climate.mit.edu/posts/computers-power-...
# 41   Mercom India  https://mercomindia.com/news-wrap-up-rec-india...
# 40   Mercom India  https://mercomindia.com/keralas-anert-bids-pro...
# 39   Mercom India  https://mercomindia.com/solar-pv-soiling-likel...
# 31       Euronews  https://www.euronews.com/2023/01/13/gas-pipeli...
# 26  Recharge News  https://www.rechargenews.com/wind/us-offshore-...
# 25  Recharge News  https://www.rechargenews.com/wind/chinas-mingy...
# 23  Recharge News  https://www.rechargenews.com/energy-transition...
# 22  Recharge News  https://www.rechargenews.com/energy-transition...
# 21  Recharge News  https://www.rechargenews.com/energy-transition...
# 24  Recharge News  https://www.rechargenews.com/energy-transition...
# 42   Mercom India  https://mercomindia.com/karnataka-cuts-deviati...
# 10            IEA  https://www.iea.org//news/the-world-is-enterin...
# 29  Recharge News  https://www.rechargenews.com/wind/thors-hammer...
# 28  Recharge News  https://www.rechargenews.com/wind/too-much-and...
# 27  Recharge News  https://www.rechargenews.com/wind/broadwind-ha...
# 43   Mercom India  https://mercomindia.com/tech-firm-entuple-e-mo...
# 1             MIT  https://climate.mit.edu/posts/study-extreme-he...
# 2             MIT  https://climate.mit.edu/posts/looking-past-pre...
# 32       Euronews  https://www.euronews.com/2023/01/11/german-pol...
# 11            IEA  https://www.iea.org//news/hydrogen-patents-ind...
# 44   Mercom India  https://mercomindia.com/silicon-ranch-raises-6...
# 3             MIT  https://climate.mit.edu/posts/new-way-assess-r...
# 45   Mercom India  https://mercomindia.com/sunrun-expand-assets-l...
# 46   Mercom India  https://mercomindia.com/karnataka-bids-solariz...
# 47   Mercom India  https://mercomindia.com/punjab-allows-discom-c...
# 48   Mercom India  https://mercomindia.com/data-based-decision-ma...
# 12            IEA  https://www.iea.org//news/executive-director-m...
# 33       Euronews  https://www.euronews.com/next/2023/01/06/recor...
# 4             MIT  https://climate.mit.edu/posts/new-mit-internsh...
# 34       Euronews  https://www.euronews.com/my-europe/2023/01/05/...
# 5             MIT  https://climate.mit.edu/posts/sustainable-supp...
# 35       Euronews  https://www.euronews.com/2022/12/28/finland-op...
# 36       Euronews  https://www.euronews.com/2022/12/26/serbians-a...
# 6             MIT  https://climate.mit.edu/posts/mit-community-20...
# 37       Euronews  https://www.euronews.com/green/2022/12/22/the-...
# 7             MIT  https://climate.mit.edu/posts/manufacturing-cl...
# 8             MIT  https://climate.mit.edu/posts/new-sensor-uses-...
# 9             MIT  https://climate.mit.edu/posts/evelyn-wang-appo...
# 38       Euronews  https://www.euronews.com/2022/12/17/hungary-ro...
# 13            IEA  https://www.iea.org//news/the-world-s-coal-con...
# 14            IEA  https://www.iea.org//news/how-the-european-uni...
# 15            IEA  https://www.iea.org//news/iea-and-ukraine-deep...
# 16            IEA  https://www.iea.org//news/global-government-sp...
# 17            IEA  https://www.iea.org//news/renewable-power-s-gr...
# 18            IEA  https://www.iea.org//news/global-energy-effici...
# 19            IEA  https://www.iea.org//news/the-global-energy-cr...

# %%
articles = data['content'].tolist()

# %%
from transformers import BartTokenizer,BartForConditionalGeneration, pipeline
model=BartForConditionalGeneration.from_pretrained('Yale-LILY/brio-cnndm-uncased')
tokenizer=BartTokenizer.from_pretrained('Yale-LILY/brio-cnndm-uncased')
summarizer=pipeline("summarization",model=model,tokenizer=tokenizer,batch_size=16,truncation=True,device=0)

# %%
summarizer(articles[0], min_length=120, do_sample=False)
# Out:
# Your max_length is set to 142, but you input_length is only 112. You might consider decreasing max_length manually, e.g. summarizer('...', max_length=56)
# [{'summary_text': 'Atlantic Shores will lease 35 acres at the New Jersey Wind Port. 1.5GW project slated to begin installation in 2026. Shell-EDF joint venture signed a letter of intent with New Jersey for marshalling space at the wind port. The lease is expected to start in mid-2026.    the project will be the Atlantic Shores offshore wind project. \xa0  \xa0\xa0 \xa0 the 1.3GW project is slated for installation in the future.\xa0\xa0\xa0 the\xa0shoreline\xa0 will be in the south of the state\xa0\xa0.'}]
